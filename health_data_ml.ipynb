# %%
import pandas as pd

# %%
data=pd.read_csv("Health_Full Data_data.csv")
df = pd.DataFrame(data)

# %%
df
# Out:
#           Country Above Threshold?        Region Health Exp % GDP  \
# 0       Mauritius  Below Threshold        Africa             4.8%
# 1      Seychelles  Below Threshold        Africa             4.7%
# 2         Tunisia  Below Threshold        Africa             7.0%
# 3    South Africa  Below Threshold        Africa             8.8%
# 4           Libya  Below Threshold        Africa             3.9%
# ..            ...              ...           ...              ...
# 203        Belize  Below Threshold  The Americas             5.8%
# 204         Haiti  Below Threshold  The Americas             6.4%
# 205       Bolivia  Below Threshold  The Americas             5.8%
# 206      Honduras  Below Threshold  The Americas             8.6%
# 207     Guatemala  Below Threshold  The Americas             6.7%
#
#     Health Exp/Capita
# 0                $444
# 1                $521
# 2                $297
# 3                $645
# 4                $578
# ..                ...
# ...

# %%
df.head()
# Out:
#         Country Above Threshold?  Region Health Exp % GDP Health Exp/Capita
# 0     Mauritius  Below Threshold  Africa             4.8%              $444
# 1    Seychelles  Below Threshold  Africa             4.7%              $521
# 2       Tunisia  Below Threshold  Africa             7.0%              $297
# 3  South Africa  Below Threshold  Africa             8.8%              $645
# 4         Libya  Below Threshold  Africa             3.9%              $578

# %%
df.tail()
# Out:
#        Country Above Threshold?        Region Health Exp % GDP  \
# 203     Belize  Below Threshold  The Americas             5.8%
# 204      Haiti  Below Threshold  The Americas             6.4%
# 205    Bolivia  Below Threshold  The Americas             5.8%
# 206   Honduras  Below Threshold  The Americas             8.6%
# 207  Guatemala  Below Threshold  The Americas             6.7%
#
#     Health Exp/Capita
# 203              $259
# 204               $53
# 205              $149
# 206              $195
# 207              $226

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 208 entries, 0 to 207
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Country            208 non-null    object
#  1   Above Threshold?   208 non-null    object
#  2   Region             208 non-null    object
#  3   Health Exp % GDP   185 non-null    object
#  4   Health Exp/Capita  185 non-null    object
# dtypes: object(5)
# memory usage: 8.3+ KB

# %%
df.isnull().sum()
# Out:
# Country               0
# Above Threshold?      0
# Region                0
# Health Exp % GDP     23
# Health Exp/Capita    23
# dtype: int64

# %%
df.describe()
# Out:
#           Country Above Threshold?  Region Health Exp % GDP Health Exp/Capita
# count         208              208     208              185               185
# unique        208                2       6               87               164
# top     Mauritius  Below Threshold  Africa             5.9%              $521
# freq            1              204      53                7                 3

# %%
df['Above Threshold?']
# Out:
# 0      Below Threshold
# 1      Below Threshold
# 2      Below Threshold
# 3      Below Threshold
# 4      Below Threshold
#             ...
# 203    Below Threshold
# 204    Below Threshold
# 205    Below Threshold
# 206    Below Threshold
# 207    Below Threshold
# Name: Above Threshold?, Length: 208, dtype: object

# %%
#Label Encoding
from sklearn.preprocessing import LabelEncoder
l=LabelEncoder()
df['Above Threshold?']=l.fit_transform(df['Above Threshold?'])

# %%
df
# Out:
#           Country  Above Threshold?        Region Health Exp % GDP  \
# 0       Mauritius                 1        Africa             4.8%
# 1      Seychelles                 1        Africa             4.7%
# 2         Tunisia                 1        Africa             7.0%
# 3    South Africa                 1        Africa             8.8%
# 4           Libya                 1        Africa             3.9%
# ..            ...               ...           ...              ...
# 203        Belize                 1  The Americas             5.8%
# 204         Haiti                 1  The Americas             6.4%
# 205       Bolivia                 1  The Americas             5.8%
# 206      Honduras                 1  The Americas             8.6%
# 207     Guatemala                 1  The Americas             6.7%
#
#     Health Exp/Capita
# 0                $444
# 1                $521
# 2                $297
# 3                $645
# 4                $578
# ...

# %%
df['Region'].unique()
# Out:
# array(['Africa', 'Asia', 'Europe', 'Middle East', 'Oceania',
#        'The Americas'], dtype=object)

# %%
map={'Africa':1, 'Asia':2, 'Europe':3, 'Middle East':4, 'Oceania':5, 'The Americas':6}
df['Region']=df['Region'].map(map)

# %%
df
# Out:
#           Country  Above Threshold?  Region Health Exp % GDP Health Exp/Capita
# 0       Mauritius                 1       1             4.8%              $444
# 1      Seychelles                 1       1             4.7%              $521
# 2         Tunisia                 1       1             7.0%              $297
# 3    South Africa                 1       1             8.8%              $645
# 4           Libya                 1       1             3.9%              $578
# ..            ...               ...     ...              ...               ...
# 203        Belize                 1       6             5.8%              $259
# 204         Haiti                 1       6             6.4%               $53
# 205       Bolivia                 1       6             5.8%              $149
# 206      Honduras                 1       6             8.6%              $195
# 207     Guatemala                 1       6             6.7%              $226
#
# [208 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 208 entries, 0 to 207
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Country            208 non-null    object
#  1   Above Threshold?   208 non-null    int64
#  2   Region             208 non-null    int64
#  3   Health Exp % GDP   185 non-null    object
#  4   Health Exp/Capita  185 non-null    object
# dtypes: int64(2), object(3)
# memory usage: 8.3+ KB

# %%
df.columns=['Country','Above Threshold','Region','Health Exp percent GDP','Health Exp per Capita']

# %%
df
# Out:
#           Country  Above Threshold  Region Health Exp percent GDP  \
# 0       Mauritius                1       1                   4.8%
# 1      Seychelles                1       1                   4.7%
# 2         Tunisia                1       1                   7.0%
# 3    South Africa                1       1                   8.8%
# 4           Libya                1       1                   3.9%
# ..            ...              ...     ...                    ...
# 203        Belize                1       6                   5.8%
# 204         Haiti                1       6                   6.4%
# 205       Bolivia                1       6                   5.8%
# 206      Honduras                1       6                   8.6%
# 207     Guatemala                1       6                   6.7%
#
#     Health Exp per Capita
# 0                    $444
# 1                    $521
# 2                    $297
# 3                    $645
# 4                    $578
# ...

# %%
print(df['Health Exp per Capita'].dtype)
# Out:
# object

# %%
df.isnull().sum()
# Out:
# Country                    0
# Above Threshold            0
# Region                     0
# Health Exp percent GDP    23
# Health Exp per Capita     23
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Country                   0
# Above Threshold           0
# Region                    0
# Health Exp percent GDP    0
# Health Exp per Capita     0
# dtype: int64

# %%
#Remove '%', '$', and ',' then convert to float
df['Health Exp percent GDP'] = df['Health Exp percent GDP'].str.replace('%', '').astype(float)
df['Health Exp per Capita'] = df['Health Exp per Capita'].str.replace('$', '')
df['Health Exp per Capita'] = df['Health Exp per Capita'].str.replace(',', '').astype(float)

# %%
df
# Out:
#           Country  Above Threshold  Region  Health Exp percent GDP  \
# 0       Mauritius                1       1                     4.8
# 1      Seychelles                1       1                     4.7
# 2         Tunisia                1       1                     7.0
# 3    South Africa                1       1                     8.8
# 4           Libya                1       1                     3.9
# ..            ...              ...     ...                     ...
# 203        Belize                1       6                     5.8
# 204         Haiti                1       6                     6.4
# 205       Bolivia                1       6                     5.8
# 206      Honduras                1       6                     8.6
# 207     Guatemala                1       6                     6.7
#
#      Health Exp per Capita
# 0                    444.0
# 1                    521.0
# 2                    297.0
# 3                    645.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 185 entries, 0 to 207
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country                 185 non-null    object
#  1   Above Threshold         185 non-null    int64
#  2   Region                  185 non-null    int64
#  3   Health Exp percent GDP  185 non-null    float64
#  4   Health Exp per Capita   185 non-null    float64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 8.7+ KB

# %%
df.describe()
# Out:
#        Above Threshold      Region  Health Exp percent GDP  \
# count       185.000000  185.000000              185.000000
# mean          0.978378    3.037838                6.807027
# std           0.145839    1.815895                2.771204
# min           0.000000    1.000000                1.800000
# 25%           1.000000    1.000000                5.000000
# 50%           1.000000    3.000000                6.400000
# 75%           1.000000    4.000000                8.500000
# max           1.000000    6.000000               17.900000
#
#        Health Exp per Capita
# count             185.000000
# mean             1077.497297
# std              1814.367000
# min                15.000000
# 25%                96.000000
# 50%               340.000000
# 75%               951.000000
# max              9055.000000

# %%
#Label Encoding
from sklearn.preprocessing import LabelEncoder
l=LabelEncoder()
df['Country']=l.fit_transform(df['Country'])

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()

scaler.fit_transform(df)
# Out:
# array([[5.81521739e-01, 1.00000000e+00, 0.00000000e+00, 1.86335404e-01,
#         4.74557522e-02],
#        [7.82608696e-01, 1.00000000e+00, 0.00000000e+00, 1.80124224e-01,
#         5.59734513e-02],
#        [9.23913043e-01, 1.00000000e+00, 0.00000000e+00, 3.22981366e-01,
#         3.11946903e-02],
#        [8.15217391e-01, 1.00000000e+00, 0.00000000e+00, 4.34782609e-01,
#         6.96902655e-02],
#        [5.16304348e-01, 1.00000000e+00, 0.00000000e+00, 1.30434783e-01,
#         6.22787611e-02],
#        [6.19565217e-01, 1.00000000e+00, 0.00000000e+00, 2.85714286e-01,
#         1.93584071e-02],
#        [1.19565217e-01, 1.00000000e+00, 0.00000000e+00, 2.17391304e-01,
#         4.08185841e-02],
#        [2.71739130e-01, 1.00000000e+00, 0.00000000e+00, 1.98757764e-01,
#         1.51548673e-02],
#        [1.08695652e-02, 1.00000000e+00, 0.00000000e+00, 2.11180124e-01,
#         2.92035398e-02],
#        [6.35869565e-01, 1.00000000e+00, 0.00000000e+00, 4.03726708e-01,
# ...

# %%
from sklearn.preprocessing import StandardScaler

Std_scaler=StandardScaler()

Std_scaler.fit_transform(df)
# Out:
# array([[ 2.80877207e-01,  1.48658829e-01, -1.12526786e+00,
#         -7.26209163e-01, -3.50103604e-01],
#        [ 9.73707652e-01,  1.48658829e-01, -1.12526786e+00,
#         -7.62392490e-01, -3.07549393e-01],
#        [ 1.46056148e+00,  1.48658829e-01, -1.12526786e+00,
#          6.98240428e-02, -4.31343460e-01],
#        [ 1.08605854e+00,  1.48658829e-01, -1.12526786e+00,
#          7.21123938e-01, -2.39020534e-01],
#        [ 5.61754415e-02,  1.48658829e-01, -1.12526786e+00,
#         -1.05185911e+00, -2.76048224e-01],
#        [ 4.11953237e-01,  1.48658829e-01, -1.12526786e+00,
#         -1.47275922e-01, -4.90477234e-01],
#        [-1.31076030e+00,  1.48658829e-01, -1.12526786e+00,
#         -5.45292525e-01, -3.83262729e-01],
#        [-7.86456181e-01,  1.48658829e-01, -1.12526786e+00,
#         -6.53842508e-01, -5.11478013e-01],
#        [-1.68526324e+00,  1.48658829e-01, -1.12526786e+00,
#         -5.81475853e-01, -4.41291198e-01],
# ...

# %%
from sklearn.linear_model import LinearRegression,Lasso,Ridge,ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor

# %%
from sklearn.model_selection import train_test_split

# %%
df
# Out:
#      Country  Above Threshold  Region  Health Exp percent GDP  \
# 0        107                1       1                     4.8
# 1        144                1       1                     4.7
# 2        170                1       1                     7.0
# 3        150                1       1                     8.8
# 4         95                1       1                     3.9
# ..       ...              ...     ...                     ...
# 203       17                1       6                     5.8
# 204       70                1       6                     6.4
# 205       20                1       6                     5.8
# 206       71                1       6                     8.6
# 207       66                1       6                     6.7
#
#      Health Exp per Capita
# 0                    444.0
# 1                    521.0
# 2                    297.0
# 3                    645.0
# 4                    578.0
# ..                     ...
# ...

# %%
X=df.drop('Health Exp per Capita',axis=1)

# %%
X
# Out:
#      Country  Above Threshold  Region  Health Exp percent GDP
# 0        107                1       1                     4.8
# 1        144                1       1                     4.7
# 2        170                1       1                     7.0
# 3        150                1       1                     8.8
# 4         95                1       1                     3.9
# ..       ...              ...     ...                     ...
# 203       17                1       6                     5.8
# 204       70                1       6                     6.4
# 205       20                1       6                     5.8
# 206       71                1       6                     8.6
# 207       66                1       6                     6.7
#
# [185 rows x 4 columns]

# %%
y=df[['Health Exp per Capita']]

# %%
y
# Out:
#      Health Exp per Capita
# 0                    444.0
# 1                    521.0
# 2                    297.0
# 3                    645.0
# 4                    578.0
# ..                     ...
# 203                  259.0
# 204                   53.0
# 205                  149.0
# 206                  195.0
# 207                  226.0
#
# [185 rows x 1 columns]

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3)

# %%
X_test
# Out:
#      Country  Above Threshold  Region  Health Exp percent GDP
# 2        170                1       1                     7.0
# 83        89                1       2                     7.1
# 75       118                1       2                     5.5
# 30        67                1       1                     6.3
# 200       49                1       6                     6.4
# 192       35                1       6                     6.8
# 86       166                1       2                     4.3
# 119       97                1       3                     6.9
# 142      125                1       4                     2.6
# 50        32                1       1                     2.8
# 179      169                1       6                     5.4
# 98       139                1       3                     6.5
# 125      160                1       3                     9.6
# 115      148                1       3                     8.8
# ...

# %%
y_test
# Out:
#      Health Exp per Capita
# 2                    297.0
# 83                    84.0
# 75                    36.0
# 30                    32.0
# 200                  361.0
# 192                  530.0
# 86                    50.0
# 119                 7452.0
# 142                  690.0
# 50                    25.0
# 179                  972.0
# 98                  3792.0
# 125                 5319.0
# 115                 1942.0
# 77                   232.0
# 91                   561.0
# 95                  5407.0
# 26                    66.0
# 133                  665.0
# 107                 6304.0
# 57                  2426.0
# 18                   115.0
# 63                   102.0
# 48                   190.0
# 85                    51.0
# 84                    55.0
# 127                  228.0
# 205                  149.0
# 123                 1949.0
# 193                  618.0
# 111                 8980.0
# 187                  340.0
# 61                   333.0
# ...

# %%
from sklearn.metrics import r2_score

# %%
models={
    "LinearRegression":LinearRegression(),
    "Lasso":Lasso(),
    "Ridge":Ridge(),
    "ElasticNet":ElasticNet(),
    "SVM":SVR(),
    "Random forest":RandomForestRegressor(),
    "Decision Tree":DecisionTreeRegressor()
}

# %%
for i in range(len(list(models))):
    model=(list(models.values())[i])
    model.fit(X_train,y_train)
    pred=model.predict(X_test)
    print(list(models.keys())[i]) #for giving headings to each model
    print(r2_score(y_test,pred))
    print("*"*30)
# Out:
# LinearRegression
# 0.15718923380720895
# ******************************
# Lasso
# 0.1585381392501981
# ******************************
# Ridge
# 0.1791812408764749
# ******************************
# ElasticNet
# 0.1978653219740547
# ******************************
# SVM
# -0.17114618524332492
# ******************************
# c:\Users\ADMIN\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\ADMIN\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Random forest
# 0.36824406648885966
# ******************************
# ...

# %%
rfr=RandomForestRegressor()
rfr.fit(X_train,y_train)
# Out:
# c:\Users\ADMIN\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestRegressor()

# %%
import pickle

with open("rfr_File.pkl","wb") as file:
    pickle.dump(rfr,file)
